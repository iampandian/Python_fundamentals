# %% [markdown]
# # Python Fundamentals
#
# Here, We will see **Object Oriented Programming** techniques.

# %% [markdown]
# Object Oriented Programmimg consist of *Encapsulation, Abstraction, Inheritance, Ploymorphism*

# %%
# creating a class and nothing do in the class 'pass'

class Car:
    pass

# %%
# declearing an object in car class

car1 = Car()

# %%
# Add some attributes with in the object
car1.brand = 'BMW'
car1.passager_type = 4
car1.color = 'Green'
car1.engine_type = 'Petrol'

# print store the value in the object
print(car1.__dict__)
# Out:
# {'brand': 'BMW', 'passager_type': 4, 'color': 'Green', 'engine_type': 'Petrol'}

# %% [markdown]
# You can see above the class, object, attributes are individualy assigned.

# %%
# Now creating class and design a constructor method?

class Car:
    #constructor
    def __init__(self, brand, passengers_type, color, engine_type):
        self.brand = brand
        self.passengers_type = passengers_type
        self.color = color
        self.engine_type =engine_type

# %%
car1 = Car('BMW', 4, 'Green', 'Petrol')

print(car1.__dict__)
# Out:
# {'brand': 'BMW', 'passengers_type': 4, 'color': 'Green', 'engine_type': 'Petrol'}

# %%
# what are the constructors in a class?
dir(Car)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %% [markdown]
# Here, we saw two constructors, `__init__` is initialize the parameter(s) and `__dict__` is a dictionary format

# %%
# inheritance 

class Car:
    #parent constructor
    def __init__(self, brand, door, color, engine_type, speed):
        self.brand = brand
        self.door = door
        self.color = color
        self.engine_type = engine_type
        self.speed = speed
        
    def car_speed(self):
        self.speed = self.speed + 5
        print(self.speed)

# %%
car1 = Car('BMW', 4, 'Green', 'Petrol', 34)
car2 = Car('Audi', 4, 'Black', 'Petrol', 29)

car1.car_speed()
# Out:
# 39

# %% [markdown]
# An instance is a specific object created from a particular class. To create instances of a class, call the class using the class name and pass in whatever arguments its `__init__` method accepts—in this example, the `__init__` method takes brand, door, color, engine_type and speed.
