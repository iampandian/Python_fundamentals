# %% [markdown]
# # Python Fundamentals
#
# The notebook has to cover the following topic:
#
# 1. I/O functions
# 2. Data types & variables
# 3. String operations
# 4. List & Tuples

# %%
#Start Print element
print("Hello, World!")
# Out:
# Hello, World!

# %%
#Get a Input from User 'input()'
print(input())
# Out:
# Machine Learning
# Machine Learning

# %%
#Variable assign and some examples
name = "John"
a_string = 'Hello, John!'
numer_1 = "John birthday is January 1, 2001"

# %%
#Single quotes
a_string = 'Python is popular language'
print(a_string)
# Out:
# Python is popular language

# %%
#Double quotes
aa_string = "Python has many frameworks and its used various applications"
print(aa_string)
# Out:
# Python has many frameworks and its used various applications

# %%
#Triple quotes or multiline statement
aaa_string = '''Python is an experiment in how much freedom programmers need.  -by Guido van Rossum'''
print(aaa_string)
# Out:
# Python is an experiment in how much freedom programmers need.  -by Guido van Rossum

# %%
#Quotes uses in-between line
in_string = "It's easy to understand"
print(in_string)
# Out:
# It's easy to understand

# %%
#Numbers
num = 12
print(num)
print(type(num))
# Out:
# 12
# <class 'int'>

# %%
#Numbers continued...!
num_1 = 9.4
print("type of num_1 is: ", type(num_1))
# Out:
# type of num_1 is:  <class 'float'>

# %%
#Numbers continued...!
num_2 = True
print("type of num_2 is: ", type(num_2))
# Out:
# type of num_2 is:  <class 'bool'>

# %%
#List
lst = [1,5,6,3,6,[3,5], 'python', 9]
print("type of lst is:", type(lst))
# Out:
# type of lst is: <class 'list'>

# %%
lst + lst
# Out:
# [1, 5, 6, 3, 6, [3, 5], 'python', 9, 1, 5, 6, 3, 6, [3, 5], 'python', 9]

# %%
# List slicing, start with index 0 
lst[3:]
# Out:
# [3, 6, [3, 5], 'python', 9]

# %%
lst[:3]
# Out:
# [1, 5, 6]

# %%
#Reverse list
lst[::-1]
# Out:
# [9, 'python', [3, 5], 6, 3, 6, 5, 1]

# %%
#List insert with end
lst.append(12)
lst
# Out:
# [1, 5, 6, 3, 6, [3, 5], 'python', 9, 12]

# %%
#Delete a number in end of the list
lst.pop()
lst
# Out:
# [1, 5, 6, 3, 6, [3, 5], 'python', 9]

# %%
#Upper case 
name = 'john mathew'
print(name.upper())
# Out:
# JOHN MATHEW

# %%
#Lower case
city = 'CALIFORNIA'
print(city.lower())
# Out:
# california

# %%
#find a index m in name
name.index('m')
# Out:
# 5

# %%
#Tuples
a_tuple = (2, 4, 5,6,3,5,2,'tuple', 'python', 5,4)
print(a_tuple)
print(type(a_tuple))
# Out:
# (2, 4, 5, 6, 3, 5, 2, 'tuple', 'python', 5, 4)
# <class 'tuple'>

# %%
# count a number
a_tuple.count(5)
# Out:
# 3

# %%
#index of a tuple
a_tuple.index(5) # first index of 5
# Out:
# 2

# %%
# tuple is immutable
a_tuple[2] = 0
a_tuple
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-5ad8d0949467> in <module>
#       1 # tuple is immutable
# ----> 2 a_tuple[2] = 0
#       3 a_tuple
#
# TypeError: 'tuple' object does not support item assignment
